# %% [markdown]
# ### Importação dos dados

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

loja.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# ...

# %% [markdown]
# # 1. Análise do faturamento

# %% [markdown]
# #  Loja 1 Faturamento total

# %%
receita_bruta_loja1 = loja.Preço.sum()
receita_bruta_loja1
# Out:
# np.float64(1534509.12)

# %% [markdown]
# Valor total arrecadado pela Loja 1: 1.534.509,12

# %% [markdown]
# #  Loja 2 Faturamento total

# %%
receita_bruta_loja2 = loja2.Preço.sum()
receita_bruta_loja2
# Out:
# np.float64(1488459.06)

# %% [markdown]
# O valor total arrecadado pela Loja 2 : 1.488.459,06

# %% [markdown]
# #  Loja 3 Faturamento total

# %%
receita_bruta_loja3 = loja3.Preço.sum()
receita_bruta_loja3
# Out:
# np.float64(1464025.03)

# %% [markdown]
# O valor total arrecadado pela Loja 3 : 1.464.025,03

# %%
receita_bruta_loja4 = loja4.Preço.sum()
receita_bruta_loja4
# Out:
# np.float64(1384497.58)

# %% [markdown]
# O valor total arrecadado pela Loja 4 : 1.384.497.58

# %%
Frete_media = ({
    "loja-1": 153450912,
    "loja-2" : 148845906,
    "loja-3": 146402503,
    "loja-4": 138449758
})

Frete = pd.Series(Frete_media)
Frete.plot(kind='barh', figsize=(8, 5), color='lightpink')
plt.title('Valor Arrecado Bruto (Em Milhões de Reais)')
plt.xlabel('Total Pago')

Frete_media
# Out:
# {'loja-1': 153450912,
#  'loja-2': 148845906,
#  'loja-3': 146402503,
#  'loja-4': 138449758}

# %%
# visualização dos valores
# loja.groupby("Produto")['Preço'].sum().sort_values()
valor_total_agrupado = loja.groupby([ "Categoria do Produto"])['Preço'].sum().sort_values(ascending=False)
valor_total_agrupado.plot( kind='line',figsize=(16,8), color='red')
# valor_total_agrupado
# Out:
# <Axes: xlabel='Categoria do Produto'>

# %%
valor_total1 = loja.groupby("Produto")['Preço'].sum().sort_values()
valor_total1.plot( kind='bar',figsize=(12,12), color='red')
# Out:
# <Axes: xlabel='Produto'>

# %%
loja['Avaliação da compra'].mean()
# Out:
# np.float64(3.976685036032217)

# %% [markdown]
# A média referente a loja 1 é de : 3.97

# %%
loja['Frete'].mean()
# Out:
# np.float64(34.69180491551149)

# %% [markdown]
# # 2. Média de Avaliação das Lojas

# %%
loja['Avaliação da compra'].mean()
# Out:
# np.float64(3.976685036032217)

# %% [markdown]
# # A avaliaçao média da loja A é 3.97

# %%
loja2['Avaliação da compra'].mean()
# Out:
# np.float64(4.037303942348453)

# %% [markdown]
# # A avaliaçao média da loja B é 4.03

# %%
loja3['Avaliação da compra'].mean()
# Out:
# np.float64(4.048325561678677)

# %% [markdown]
# # A avaliaçao média da loja C é 4.04

# %%
loja4['Avaliação da compra'].mean()
# Out:
# np.float64(3.9957591178965224)

# %% [markdown]
# # A avaliaçao média da loja D é 3.99

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %% [markdown]
# --------------        Loja 1 ----------------

# %%
valor_total1 = loja.groupby("Produto")['Preço'].sum().sort_values()
valor_total1.plot( kind='bar',figsize=(12,12), color='orange')
# Out:
# <Axes: xlabel='Produto'>

# %% [markdown]
# A partir da geração do Gráfico, podemos tirar as seguintes conclusões acerca da loja 1:
#
# - Os 5 Produtos que mais geram RECEITA : 4 Pertecem a categoria de eletrodomésticos (TV's, Geladeiras e Lavadoras)
#     TV Led UHD 4K                  189534.28
#     Geladeira                      149524.28
#     Celular Plus X42               130536.40
#     Smart TV                        89936.15
#     Lavadora de roupas              87711.30
# - Os 5 Produtos que menos geram receita (Todos pertecem a categoria de brinquedos)
#     Corda de pular                    870.89
#     Dinossauro Rex                    918.40
#     Cubo mágico 8x8                   929.27
#     Jogo de copos                    1812.15
#     Xadrez de madeira                1907.42

# %%
# visualização dos valores
# loja.groupby("Produto")['Preço'].sum().sort_values()
valor_total_agrupado = loja.groupby([ "Categoria do Produto"])['Preço'].sum().sort_values(ascending=False)
valor_total_agrupado.plot( kind='line',figsize=(16,8), color='orange')
# valor_total_agrupado
# Out:
# <Axes: xlabel='Categoria do Produto'>

# %% [markdown]
# ------------------------------Loja 2 ---------------------

# %%
valor_total2 = loja2.groupby("Produto")['Preço'].sum().sort_values()
valor_total2.plot( kind='bar',figsize=(12,12), color='green')
# Out:
# <Axes: xlabel='Produto'>

# %% [markdown]
# A partir da geração do Gráfico, podemos tirar as seguintes conclusões acerca da loja 2:
#
# - Os 5 Produtos que mais geram RECEITA : 4 Pertecem a categoria de eletrodomésticos (TV's, Geladeiras e Lavadoras)
#     TV Led UHD 4K                  189534.28
#     Geladeira                      149524.28
#     Celular Plus X42               130536.40
#     Smart TV                        89936.15
#     Lavadora de roupas              87711.30
# - Os 5 Produtos que menos geram receita (Todos pertecem a categoria de brinquedos)
#     Corda de pular                    870.89
#     Dinossauro Rex                    918.40
#     Cubo mágico 8x8                   929.27
#     Jogo de copos                    1812.15
#     Xadrez de madeira                1907.42

# %%
valor_total_agrupado2 = loja2.groupby([ "Categoria do Produto"])['Preço'].sum().sort_values(ascending=False)  
valor_total_agrupado2
# Out:
# Categoria do Produto
# eletronicos              547773.71
# eletrodomesticos         464758.13
# moveis                   235234.68
# instrumentos musicais    139987.03
# esporte e lazer           46326.09
# brinquedos                21262.21
# utilidades domesticas     19662.86
# livros                    13454.35
# Name: Preço, dtype: float64

# %%
# visualização dos valores
# loja.groupby("Produto")['Preço'].sum().sort_values()
valor_total_agrupado2 = loja2.groupby([ "Categoria do Produto"])['Preço'].sum().sort_values(ascending=False)
valor_total_agrupado2.plot( kind='line',figsize=(16,8), color='orange')
# valor_total_agrupado
# Out:
# <Axes: xlabel='Categoria do Produto'>

# %% [markdown]
# ----------------------- Loja 3 -------------

# %%
valor_total3 = loja3.groupby("Produto")['Preço'].sum().sort_values()
valor_total3.plot( kind='bar',figsize=(12,12), color='purple')
# Out:
# <Axes: xlabel='Produto'>

# %%
valor_total_agrupado3 = loja3.groupby([ "Categoria do Produto"])['Preço'].sum().sort_values(ascending=False)  
valor_total_agrupado3
# Out:
# Categoria do Produto
# eletronicos              547699.92
# eletrodomesticos         438984.89
# moveis                   268095.56
# instrumentos musicais    103174.45
# esporte e lazer           47456.10
# brinquedos                25869.20
# utilidades domesticas     20080.21
# livros                    12664.70
# Name: Preço, dtype: float64

# %%
# visualização dos valores
# loja.groupby("Produto")['Preço'].sum().sort_values()
valor_total_agrupado3 = loja3.groupby([ "Categoria do Produto"])['Preço'].sum().sort_values(ascending=False)
valor_total_agrupado3.plot( kind='line',figsize=(16,8), color='lightgreen')
# valor_total_agrupado
# Out:
# <Axes: xlabel='Categoria do Produto'>

# %% [markdown]
# # Loja 4

# %%
valor_total4 = loja4.groupby("Produto")['Preço'].sum().sort_values()
valor_total4.plot( kind='bar',figsize=(12,12), color='lightgreen')
# Out:
# <Axes: xlabel='Produto'>

# %%
valor_total_agrupado4 = loja4.groupby([ "Categoria do Produto"])['Preço'].sum().sort_values(ascending=False)  
valor_total_agrupado4
# Out:
# Categoria do Produto
# eletronicos              545966.86
# eletrodomesticos         377680.65
# moveis                   256705.65
# instrumentos musicais    100136.50
# esporte e lazer           44465.65
# brinquedos                27015.67
# utilidades domesticas     20098.83
# livros                    12427.77
# Name: Preço, dtype: float64

# %% [markdown]
# # 5. Frete Médio por Loja

# %%
Frete_media = ({
    "loja-1": 34.70 ,
    "loja-2" : 33.62,
    "loja-3": 33.07,
    "loja-4": 31.27
})

Frete = pd.Series(Frete_media)
Frete.plot(kind='barh', figsize=(8, 5), color='lightblue')
plt.title('Valor do Frete médio por Loja (Em Reais)')
plt.xlabel('Total Pago')

Frete_media
# Out:
# {'loja-1': 34.7, 'loja-2': 33.62, 'loja-3': 33.07, 'loja-4': 31.27}

# %%
loja['Frete'].mean()
# Out:
# np.float64(34.69180491551149)

# %% [markdown]
# o valor do Frete médio da loja 1 é de : R$ 34.70

# %%
loja2['Frete'].mean()
# Out:
# np.float64(33.62194065817927)

# %% [markdown]
# O valor do Frete médio da loja 2 é de : 33.62

# %%
loja3['Frete'].mean()
# Out:
# np.float64(33.07446427411743)

# %% [markdown]
# O valor do Frete médio da loja 3 é de : 33.07

# %%
loja4['Frete'].mean()
# Out:
# np.float64(31.278997081841727)

# %% [markdown]
# O valor do Frete médio da loja 4 é de : 31.27
